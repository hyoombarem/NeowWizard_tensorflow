# %%
# 3장 Keras

# keras는 딥러닝 사용을 유저친화적이게 해놓으면서 짜놓은 유틸 도구

# %%
# 케라스 사용 순서

# 데이터 생성
# 오벨 구축
# 모델 컴파일
# 모델 학습
# 모델 평가 및 예측
# 모델 저장

# %%
import tensorflow.keras

# %%
# 모델 구축 파트
model = Sequential()
model.add(Flatten(input_shape = (1.))) # 입력층
model.add(Dense(2, activation = 'sigmoid')) # 은닉층
model.add(Dense(1, activation = 'sigmoid')) # 출력층

# %%
# 모델 컴파일 파트
model.compile(optimizer= SGD(learning_rate = 0.1), loss = "mse", metrics = ["accuracy"])
# 최적화 알고리즘 SGD, 학습률 0.1, 오차함수 MSE, 매트릭은 accuracy (기본은 loss)

model.compile(optimizer = Adam(learning_rate = 0.0001), loss = "categorical_crossentropy")
# 최적화 알고리즘 Adam, 학습률 0.0001, 오차함수 categorical_crossentropy

# %%
# 모델 학습 파트
model.fit(x_train, y_train, epochs = 10, batch_size = 100, verdose = 0, validation_split = 0.2)
# 첫 인자는 학습데이터, 다음 인자는 정답데이터, 전체 데이터를 10번 반복, 배치크기 = 100, 학습데이터의 20%를 검증데이터로 사용함

# %%
# 모델 평가
model.evaluate(x_tset, y_test, epochs = 10, batch_size = 100)
# 첫 인자는 테스트데이터, 다음 인자는 정답데이터, 배치사이즈 100

model.predict(x_input_data, batch_size = 100)
# 첫 인자는 예측하고자 하는 데이터

# %%
# 모델 저장
model.save("model_name.h5")
# 학습이 끝난 모델을 h5 파일로 저장

model = tensorflow.keras.models.load_model("model_name.h5")
# 저앚ㅇ되엉 있는 모델을 불러옴

# %%
print()

# %% [markdown]
# ### 통합해서 작성해보자

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import SGD

import numpy as np

print(tf.__version__)
# Out:
# 2.5.0

# %%
x_data = np.array([1, 2, 3, 4, 5, 6])
y_data = np.array([3, 4, 5, 6, 7, 8])

# %%
model = Sequential()
model.add(Flatten(input_shape = (1, )))
model.add(Dense(1, activation = "linear"))

# %%
model.compile(optimizer = SGD(learning_rate = 1e-2), loss = "mse")
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 1)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_data, y_data, epochs = 10000)
# Out:
# Epoch 1/10000
# 1/1 [==============================] - 0s 213ms/step - loss: 103.0761
# Epoch 2/10000
# 1/1 [==============================] - 0s 999us/step - loss: 47.9133
# Epoch 3/10000
# 1/1 [==============================] - 0s 1ms/step - loss: 22.3808
# Epoch 4/10000
# 1/1 [==============================] - 0s 1ms/step - loss: 10.5621
# Epoch 5/10000
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0906
# Epoch 6/10000
# 1/1 [==============================] - 0s 1000us/step - loss: 2.5567
# Epoch 7/10000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3825
# Epoch 8/10000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8376
# Epoch 9/10000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5840
# Epoch 10/10000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4652
# Epoch 11/10000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4087
# Epoch 12/10000
# ...

# %%
result = model.predict([-3.1, 3.0, 5.3, -22.0])
print(result)
# Out:
# [[ -1.1000311]
#  [  4.999995 ]
#  [  7.300005 ]
#  [-20.000113 ]]
